# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13
import cmocean.cm as cmo
import xarray as xr
import numpy as np
import xarray as xr

from xmitgcm import open_mdsdataset
data_dir = '/data/SO3/edavenport/tpose6/sep2012/velocity_assim_0825/run_iter22/'
grid_dir = '/data/SO6/TPOSE_diags/tpose6/grid_6/'

prefix = 'diag_state'

offset = 10
num_diags = 30+31+offset #sep, oct + 10 days
itPerFile = 72 # 1 day
intervals = range(itPerFile,itPerFile*num_diags,itPerFile)

ds = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2012-09-01',delta_t=1200)

num_diags = 30+31+offset# nov, dec (starting from nov 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/nov2012/run_iter20/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2012-11-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds,ds_new],dim='time')

num_diags = 31+28+offset # jan, feb, (starting from jan 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/jan2013/run_iter14/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2013-01-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds_tpose_TAO,ds_new],dim='time')

num_diags = 31+30+31+30 # mar, apr, may, june (starting from jan 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/mar2013/run_iter16/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2013-03-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds_tpose_TAO,ds_new],dim='time')

ds_tpose_TAO['XC'] = ds_tpose_TAO.XC.astype(float)
ds_tpose_TAO['YC'] = ds_tpose_TAO.YC.astype(float)
ds_tpose_TAO['Z'] = ds_tpose_TAO.Z.astype(float)
ds_tpose_TAO['XG'] = ds_tpose_TAO.XG.astype(float)
ds_tpose_TAO['YG'] = ds_tpose_TAO.YG.astype(float)

# %%
fig, ax = plt.subplots(figsize=(10,15),nrows=4)
ds_tpose_TAO['UVEL'].sel(Z=0,method='nearest').isel(time=0).plot(ax=ax[0],x='XG',y='YC',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[0].set_title('Surface (Z=0 m)')
ds_tpose_TAO['UVEL'].sel(Z=-500,method='nearest').isel(time=0).plot(ax=ax[1],x='XG',y='YC',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[1].set_title('Z=-500 m')
ds_tpose_TAO['UVEL'].sel(Z=-1200,method='nearest').isel(time=0).plot(ax=ax[2],x='XG',y='YC',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[2].set_title('Z=-1200 m')
ds_tpose_TAO['UVEL'].sel(Z=-3000,method='nearest').isel(time=0).plot(ax=ax[3],x='XG',y='YC',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[3].set_title('Z=-3000 m')
plt.tight_layout()
fig.savefig('tpose_UVEL_IC_wt.png',dpi=300)

# %%
fig, ax = plt.subplots(figsize=(10,15),nrows=4)
ds_tpose_TAO['VVEL'].sel(Z=0,method='nearest').isel(time=0).plot(ax=ax[0],x='XC',y='YG',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[0].set_title('Surface (Z=0 m)')
ds_tpose_TAO['VVEL'].sel(Z=-500,method='nearest').isel(time=0).plot(ax=ax[1],x='XC',y='YG',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[1].set_title('Z=-500 m')
ds_tpose_TAO['VVEL'].sel(Z=-1200,method='nearest').isel(time=0).plot(ax=ax[2],x='XC',y='YG',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[2].set_title('Z=-1200 m')
ds_tpose_TAO['VVEL'].sel(Z=-3000,method='nearest').isel(time=0).plot(ax=ax[3],x='XC',y='YG',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[3].set_title('Z=-3000 m')
plt.tight_layout()
fig.savefig('tpose_VVEL_IC_wt.png',dpi=300)

# %%
ds_tpose_TAO['UVEL'].isel(time=0).max(dim='Z').plot(x='XG',y='YC',cmap=cmo.balance,vmin=-1.5,vmax=1.5)

# %%
ds_tpose_TAO['UVEL'].isel(time=0).min(dim='Z').plot(x='XG',y='YC',cmap=cmo.balance,vmin=-1.5,vmax=1.5)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13
import cmocean.cm as cmo
import xarray as xr
import numpy as np
import xarray as xr

from xmitgcm import open_mdsdataset
data_dir = '/data/SO3/edavenport/tpose6/tpose6_UV_sigma/sep2012/run_iter24/'
grid_dir = '/data/SO6/TPOSE_diags/tpose6/grid_6/'

prefix = 'diag_state'

offset = 10
num_diags = 30+31+offset #sep, oct + 10 days
itPerFile = 72 # 1 day
intervals = range(itPerFile,itPerFile*num_diags,itPerFile)

ds = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2012-09-01',delta_t=1200)

num_diags = 30+31+offset# nov, dec (starting from nov 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/tpose6_UV_sigma/nov2012/run_iter16/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2012-11-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds,ds_new],dim='time')

num_diags = 31+28+offset # jan, feb, (starting from jan 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/tpose6_UV_sigma/jan2013/run_iter17/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2013-01-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds_tpose_TAO,ds_new],dim='time')

num_diags = 31+30+31+30 # mar, apr, may, june (starting from jan 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/tpose6_UV_sigma/mar2013/run_iter20/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2013-03-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds_tpose_TAO,ds_new],dim='time')

ds_tpose_TAO['XC'] = ds_tpose_TAO.XC.astype(float)
ds_tpose_TAO['YC'] = ds_tpose_TAO.YC.astype(float)
ds_tpose_TAO['Z'] = ds_tpose_TAO.Z.astype(float)
ds_tpose_TAO['XG'] = ds_tpose_TAO.XG.astype(float)
ds_tpose_TAO['YG'] = ds_tpose_TAO.YG.astype(float)

# %%
fig, ax = plt.subplots(figsize=(10,15),nrows=4)
ds_tpose_TAO['UVEL'].sel(Z=0,method='nearest').isel(time=0).plot(ax=ax[0],x='XG',y='YC',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[0].set_title('Surface (Z=0 m)')
ds_tpose_TAO['UVEL'].sel(Z=-500,method='nearest').isel(time=0).plot(ax=ax[1],x='XG',y='YC',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[1].set_title('Z=-500 m')
ds_tpose_TAO['UVEL'].sel(Z=-1200,method='nearest').isel(time=0).plot(ax=ax[2],x='XG',y='YC',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[2].set_title('Z=-1200 m')
ds_tpose_TAO['UVEL'].sel(Z=-3000,method='nearest').isel(time=0).plot(ax=ax[3],x='XG',y='YC',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[3].set_title('Z=-3000 m')
plt.tight_layout()
fig.savefig('tpose_UVEL_IC_sigma.png',dpi=300)

# %%
fig, ax = plt.subplots(figsize=(10,15),nrows=4)
ds_tpose_TAO['VVEL'].sel(Z=0,method='nearest').isel(time=0).plot(ax=ax[0],x='XC',y='YG',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[0].set_title('Surface (Z=0 m)')
ds_tpose_TAO['VVEL'].sel(Z=-500,method='nearest').isel(time=0).plot(ax=ax[1],x='XC',y='YG',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[1].set_title('Z=-500 m')
ds_tpose_TAO['VVEL'].sel(Z=-1200,method='nearest').isel(time=0).plot(ax=ax[2],x='XC',y='YG',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[2].set_title('Z=-1200 m')
ds_tpose_TAO['VVEL'].sel(Z=-3000,method='nearest').isel(time=0).plot(ax=ax[3],x='XC',y='YG',cmap=cmo.balance,vmin=-0.5,vmax=0.5)
ax[3].set_title('Z=-3000 m')
plt.tight_layout()
fig.savefig('tpose_VVEL_IC_sigma.png',dpi=300)
